# %%
import pandas as pd

df = pd.read_csv("customer_ml_data.csv")
df.head()

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    user="MAMEDIARRA144",
    password="AissatouNgom1994@",
    account="IQB68372.us-west-2",
    warehouse="TON_WAREHOUSE",
    database="TON_DATABASE",
    schema="ANALYTICS"
)

cur = conn.cursor()
cur.execute("SELECT COUNT(*) FROM SALES_ENRICHED")
print(cur.fetchone())

cur.close()
conn.close()

# %%
print("HELLO WORLD")
